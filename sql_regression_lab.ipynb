# %%
# import modules and get pwd

import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %%
# retrive data from sql

connection_string = 'mysql+pymysql://root:' + password + '@localhost/sakila'
engine = create_engine(connection_string)
query = '''SELECT f.film_id, f.title, f.release_year, f.rental_rate, f.special_features, f.rental_duration, f.length, f.rating,
            f.language_id FROM film AS f'''



data = pd.read_sql_query(query, engine)
data.head()
# Out:
#    film_id             title  release_year  rental_rate  \
# 0        1  ACADEMY DINOSAUR          2006         0.99
# 1        2    ACE GOLDFINGER          2006         4.99
# 2        3  ADAPTATION HOLES          2006         2.99
# 3        4  AFFAIR PREJUDICE          2006         2.99
# 4        5       AFRICAN EGG          2006         2.99
#
#                    special_features  rental_duration  length rating  \
# 0  Deleted Scenes,Behind the Scenes                6      86     PG
# 1           Trailers,Deleted Scenes                3      48      G
# 2           Trailers,Deleted Scenes                7      50  NC-17
# 3    Commentaries,Behind the Scenes                5     117      G
# 4                    Deleted Scenes                6     130      G
#
#    language_id
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
def rentals_month(engine, month, year):
    """
    This function takes the rental data from Sakila and returns a Pandas DataFrame
  
    -Output:  A pandas DataFrame containing the rental data for the specified month and year.
    """
    # create the SQL query
    query = "SELECT * FROM rental WHERE MONTH(rental_date) = "+str(month)+" AND YEAR(rental_date) = "+str(year)
    
    # execute the query and store the results in a DataFrame
    data = pd.read_sql_query(query, engine)
    return data
